# %%
import matplotlib.pyplot as plt
import pandas as pd

# 创建数据
data = {
    "": ["Precision", "Recall", "F1 score"],
    "rising": [0.95, 0.88, 0.92],
    "hold": [0.96, 0.89, 0.93],
    "drop": [0.95, 0.88, 0.92]
}

df = pd.DataFrame(data)

# 创建一个figure和axis
fig, ax = plt.subplots()

# 隐藏图表的轴
ax.axis('tight')
ax.axis('off')

# 将数据添加到表格中
ax.table(cellText=df.values, colLabels=df.columns, loc='center',cellLoc='center')
fig.show()
# Out:
# C:\Users\tony\AppData\Local\Temp\ipykernel_20272\3329640766.py:23: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
